# %%
from ultralytics import YOLO
from app.model_handler import YoloType
from app.utils import process_yolo_result
from PIL import Image
import os

# %%
path = "/home/al-fazli/Desktop"
l = os.listdir(path)
l = [Image.open(os.path.join(path,i)) for i in l]

# %%
model = YOLO(YoloType.Pretrained.yolo11n.value)

# %%
res = model(l,verbose=False)

# %%
Image.fromarray(res[3].plot()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>

# %%
a = process_yolo_result(res[3])

# %%
from numpy import array

# %%
Image.fromarray(res[3].orig_img[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>

# %%
res[3].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5., 2., 2., 2., 2., 2., 2., 9.], device='cuda:0')
# conf: tensor([0.9479, 0.9034, 0.8751, 0.8703, 0.7591, 0.5410, 0.5343, 0.4744], device='cuda:0')
# data: tensor([[1.7869e+02, 1.0365e+02, 6.1918e+02, 4.5969e+02, 9.4791e-01, 5.0000e+00],
#         [3.7596e-01, 3.1737e+02, 1.3755e+02, 4.3647e+02, 9.0342e-01, 2.0000e+00],
#         [7.2871e+02, 2.7855e+02, 7.9965e+02, 4.4952e+02, 8.7505e-01, 2.0000e+00],
#         [6.4305e+02, 3.0878e+02, 7.5242e+02, 3.8523e+02, 8.7026e-01, 2.0000e+00],
#         [6.0882e+02, 3.0267e+02, 6.6049e+02, 3.7491e+02, 7.5906e-01, 2.0000e+00],
#         [1.5411e+02, 3.1613e+02, 1.8651e+02, 3.4406e+02, 5.4100e-01, 2.0000e+00],
#         [1.1115e+02, 3.2302e+02, 1.4205e+02, 3.4401e+02, 5.3432e-01, 2.0000e+00],
#         [6.1669e+02, 2.2685e+02, 6.3354e+02, 2.5623e+02, 4.7436e-01, 9.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (600, 800)
# shape: torch.Size([8, 6])
# xywh: tensor([[398.9349, 281.6664, 440.4967, 356.0385],
#         [ 68.9609, 376.9169, 137.1700, 119.1011],
#         [764.1843, 364.0358,  70.9403, 170.9729],
#         [697.7364, 347.0035, 109.3732,  76.4503],
#         [634.6552, 338.7933,  51.6790,  72.2411],
#         [170.3081, 330.0904,  32.4014,  27.9301],
#         [126.5980, 333.5137,  30.9032,  20.9938],
#         [625.1184, 241.5428,  16.8470,  29.3842]], device='cuda:0')
# xywhn: tensor([[0.4987, 0.4694, 0.5506, 0.5934],
#         [0.0862, 0.6282, 0.1715, 0.1985],
#         [0.9552, 0.6067, 0.0887, 0.2850],
#         [0.8722, 0.5783, 0.1367, 0.1274],
#         [0.7933, 0.5647, 0.0646, 0.1204],
#         [0.2129, 0.5502, 0.0405, 0.0466],
#         [0.1582, 0.5559, 0.0386, 0.0350],
#         [0.7814, 0.4026, 0.0211, 0.0490]], device='cuda:0')
# xyxy: tensor([[1.7869e+02, 1.0365e+02, 6.1918e+02, 4.5969e+02],
#         [3.7596e-01, 3.1737e+02, 1.3755e+02, 4.3647e+02],
#         [7.2871e+02, 2.7855e+02, 7.9965e+02, 4.4952e+02],
#         [6.4305e+02, 3.0878e+02, 7.5242e+02, 3.8523e+02],
#         [6.0882e+02, 3.0267e+02, 6.6049e+02, 3.7491e+02],
#         [1.5411e+02, 3.1613e+02, 1.8651e+02, 3.4406e+02],
#         [1.1115e+02, 3.2302e+02, 1.4205e+02, 3.4401e+02],
#         [6.1669e+02, 2.2685e+02, 6.3354e+02, 2.5623e+02]], device='cuda:0')
# xyxyn: tensor([[2.2336e-01, 1.7275e-01, 7.7398e-01, 7.6614e-01],
#         [4.6995e-04, 5.2894e-01, 1.7193e-01, 7.2745e-01],
#         [9.1089e-01, 4.6425e-01, 9.9957e-01, 7.4920e-01],
#         [8.0381e-01, 5.1463e-01, 9.4053e-01, 6.4205e-01],
#         [7.6102e-01, 5.0445e-01, 8.2562e-01, 6.2486e-01],
#         [1.9263e-01, 5.2688e-01, 2.3314e-01, 5.7343e-01],
#         [1.3893e-01, 5.3836e-01, 1.7756e-01, 5.7335e-01],
#         [7.7087e-01, 3.7808e-01, 7.9193e-01, 4.2706e-01]], device='cuda:0')
